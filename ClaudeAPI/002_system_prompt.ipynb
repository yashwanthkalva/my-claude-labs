# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Create an API client
from anthropic import Anthropic
client=Anthropic()
model= "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)    

def chat(messages, system=None):
    params = {   
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

messages = []

system = """ You are a patient math tutor. Do not directly answer a student's questions. Guide them to a solution step by step"""
add_user_message(messages, "How do I solve5x+3=2 for x?")
answer = chat(messages,system=system)  
answer
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 40
#      36 messages = []
#      37
#      38 system = """ You are a patient math tutor. Do not directly answer a student's questions. Guide them to a solution step by step"""
#      39 add_user_message(messages, "How do I solve5x+3=2 for x?")
# ---> 40 answer = chat(messages,system=system)
#      41 answer
#
# Cell In[1], line 33, in chat(messages, system)
#      29
#      30     if system:
#      31         params["system"] = system
#      32
# ---> 33     message = client.messages.create(**params)
#      34     return message.content[0].text
#
# File ~/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:968, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#     961     warnings.warn(
#     962         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     963         UserWarning,
#     964         stacklevel=3,
#     965     )
#     967 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# --> 968 return self._post(
#     969     "/v1/messages",
#     970     body=maybe_transform(
#     971         {
#     972             "max_tokens": max_tokens,
#     973             "messages": messages,
#     974             "model": model,
#     975             "cache_control": cache_control,
#     976             "container": container,
#     977             "inference_geo": inference_geo,
#     978             "metadata": metadata,
#     979             "output_config": output_config,
#     980             "service_tier": service_tier,
#     981             "stop_sequences": stop_sequences,
#     982             "stream": stream,
#     983             "system": system,
#     984             "thinking": thinking,
#     985             "tool_choice": tool_choice,
#     986             "tools": tools,
#     987         },
#     988         message_create_params.MessageCreateParamsStreaming
#     989         if stream
#     990         else message_create_params.MessageCreateParamsNonStreaming,
#     991     ),
#     992     options=make_request_options(
#     993         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     994     ),
#     995     cast_to=Message,
#     996     stream=stream or False,
#     997     stream_cls=Stream[RawMessageStreamEvent],
#     998 )
#
# File ~/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1490, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1486     raise TypeError("Passing both `files` and `content` is not supported")
#    1487 opts = FinalRequestOptions.construct(
#    1488     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1489 )
# -> 1490 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1174, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1171     if not response.is_closed:
#    1172         response.read()
# -> 1174     raise self._make_status_error_from_response(response) from None
#    1176 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'anthropic-workspace-id is required when authenticating with an identity-linked API key; send the id of the workspace this request acts in.'}, 'request_id': None}
