# %%
# Install dependencies
# %pip install anthropic python-dotenv

# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Create an API client
from anthropic import Anthropic
client=Anthropic()
model= "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)    

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# Make a request
try:
    """message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=[
            # List of messages to send
            {
                "role": "user",
                "content": "What is quantum computing? Answer in one sentence"
            }
        ]
    )
    print(message.content[0].text)

    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=[
            # List of messages to send
            {
                "role": "user",
                "content": "Write another sentence"
            }
        ]
    ) 
    print(message.content[0].text)"""

    # Make a starting list of messages
    messages = []

    # Add in the initial user question of "Define quantum computing in one sentence"
    add_user_message(messages, "Define quantum computing in one sentence")

    # pass the list of messages into 'chat' toget an answer
    answer = chat(messages)
    print(answer)

    add_assistant_message(messages, answer)
    print(messages)
    add_user_message(messages, "Write another sentence")
    answer = chat(messages)
    print(answer)
except Exception as error:
    message = None
    print(f"Anthropic API request failed: {error}")
# Out:
# Requirement already satisfied: anthropic in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (1.0.0)
# Requirement already satisfied: python-dotenv in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (1.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio<2,>=1 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from httpx2<3,>=2.0.0->anthropic) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Requirement already satisfied: h11>=0.16 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/yashwanth.kalva/Codebase/my-claude-code-architect-labs/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# **Quantum computing** is a type of computation that harnesses quantum mechanical phenomena — such as superposition and entanglement — to process information in ways that can solve certain complex problems exponentially faster than classical computers.
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'}, {'role': 'assistant', 'content': '**Quantum computing** is a type of computation that harnesses quantum mechanical phenomena — such as superposition and entanglement — to process information in ways that can solve certain complex problems exponentially faster than classical computers.'}]
# Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use **qubits** that can exist in multiple states simultaneously, allowing them to perform vast numbers of calculations at the same time.
